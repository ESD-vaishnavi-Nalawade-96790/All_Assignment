# %% [markdown]
# # program1-header1

# %% [markdown]
# ## program-header2

# %% [markdown]
# ### program-header3

# %% [markdown]
# #### program-header4

# %% [markdown]
# ##### program-header5

# %% [markdown]
# ###### program-header6

# %%
print("Hello world")
# Out:
# Hello world

# %%
num = 100
print(num)
# Out:
# 100

# %%
num
# Out:
# 100

# %%
print(f"num = {num}")
# Out:
# num = 100

# %%
a = 10
b = 20
print(a+b)
# Out:
# 30
